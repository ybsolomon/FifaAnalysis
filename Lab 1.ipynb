# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data.csv', index_col=0)
df
# Out:
#            ID                Name  Age  \
# 0      158023            L. Messi   31
# 1       20801   Cristiano Ronaldo   33
# 2      190871           Neymar Jr   26
# 3      193080              De Gea   27
# 4      192985        K. De Bruyne   27
# ...       ...                 ...  ...
# 18202  238813        J. Lundstram   19
# 18203  243165  N. Christoffersson   19
# 18204  241638           B. Worman   16
# 18205  246268      D. Walker-Rice   17
# 18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4      https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# ...                                               ...         ...
# ...

# %% [markdown]
# # Question 1

# %%
df.Age.mean()
# Out:
# 25.122205745043114

# %%
df[df['Age'] == df.Age.max()]
# Out:
#           ID      Name  Age                                           Photo  \
# 4741  140029  O. Pérez   45  https://cdn.sofifa.org/players/4/19/140029.png
#
#      Nationality                                 Flag  Overall  Potential  \
# 4741      Mexico  https://cdn.sofifa.org/flags/83.png       71         71
#
#          Club                                        Club Logo  ... Composure  \
# 4741  Pachuca  https://cdn.sofifa.org/teams/2/light/110147.png  ...      62.0
#
#      Marking  StandingTackle SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 4741    23.0            12.0          11.0      70.0        64.0       65.0
#
#      GKPositioning GKReflexes Release Clause
# 4741          73.0       74.0          €272K
#
# [1 rows x 88 columns]

# %%
salaries = df['Release Clause'].str.strip('€MK')
salaries.astype(float).max()
# Out:
# 999.0

# %%
df['Release Clause'].sort_values().index[-1]
# Out:
# 18183

# %%
df.describe()
# Out:
#                   ID           Age       Overall     Potential       Special  \
# count   18207.000000  18207.000000  18207.000000  18207.000000  18207.000000
# mean   214298.338606     25.122206     66.238699     71.307299   1597.809908
# std     29965.244204      4.669943      6.908930      6.136496    272.586016
# min        16.000000     16.000000     46.000000     48.000000    731.000000
# 25%    200315.500000     21.000000     62.000000     67.000000   1457.000000
# 50%    221759.000000     25.000000     66.000000     71.000000   1635.000000
# 75%    236529.500000     28.000000     71.000000     75.000000   1787.000000
# max    246620.000000     45.000000     94.000000     95.000000   2346.000000
#
#        International Reputation     Weak Foot   Skill Moves  Jersey Number  \
# count              18159.000000  18159.000000  18159.000000   18147.000000
# mean                   1.113222      2.947299      2.361308      19.546096
# ...

# %% [markdown]
# # Question 2

# %%
df.hist(column='Age', color='grey')
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>]], dtype=object)

# %%
# From this histogram, I've discovered that the majority of players fall between 20-30 years of age.

# %% [markdown]
# # Question 3

# %%
corr = df.corr()
corr
# Out:
#                                 ID       Age   Overall  Potential   Special  \
# ID                        1.000000 -0.739208 -0.417025   0.047074 -0.231352
# Age                      -0.739208  1.000000  0.452350  -0.253312  0.236695
# Overall                  -0.417025  0.452350  1.000000   0.660939  0.606960
# Potential                 0.047074 -0.253312  0.660939   1.000000  0.383727
# Special                  -0.231352  0.236695  0.606960   0.383727  1.000000
# International Reputation -0.356191  0.253765  0.499491   0.372993  0.292208
# Weak Foot                -0.075784  0.059867  0.212015   0.162346  0.341855
# Skill Moves              -0.056914  0.027649  0.414463   0.354290  0.763412
# Jersey Number             0.182074 -0.241156 -0.218931  -0.010474 -0.133716
# Crossing                 -0.131994  0.130545  0.394972   0.246319  0.866417
# Finishing                -0.082323  0.068660  0.332515   0.243355  0.724244
# ...

# %%
# One correlation that makes sense to me is that the higher the age, the less potential there is for an athlete.
# At that point in their career they have improved themselves about as much as they can before plateuing for a couple 
# of years and then retiring

# Reputation and Overall Stats being positively correlated make a lot of sense because if
# someone is very goot at playing the game they will be able to garner praise from others
# and make people think highly of them.

# %% [markdown]
# # Question 4

# %%
sns.heatmap(corr)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Question 5

# %%
plt.scatter(x=df['Age'], y=df['Potential'])
plt.title('Age vs Potential')
plt.xlabel('Age')
plt.ylabel('Potential')
plt.ylim(0,100)

plt.show()

# %%
plt.scatter(x=df['Composure'], y=df['Overall'])
plt.title('Composure vs Overall')
plt.xlabel('Composure')
plt.ylabel('Overall')
plt.ylim(0,100)

plt.show()

# %%
plt.scatter(x=df['BallControl'], y=df['ShortPassing'])
plt.title('Ball Control vs Short Passing')
plt.xlabel('Ball Control')
plt.ylabel('Short Passing')
plt.ylim(0,100)

plt.show()
